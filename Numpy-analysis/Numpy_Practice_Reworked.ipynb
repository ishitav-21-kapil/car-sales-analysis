# %% [markdown]
# # NumPy Practice Project (Reworked Exercises)
# Solve each task in the code cell below it.

# %%
# Import NumPy using the standard alias and create 1D, 2D and 3D arrays for practice.

# %%
# Inspect your arrays by finding shape, dimensions, data type, size and Python object type.

# %%
# Convert one NumPy array into a Pandas DataFrame and observe tabular representation.

# %%
# Create arrays filled with ones and zeros using specific shapes.

# %%
# Generate arrays using arange with custom step values.

# %%
# Create random integer arrays and random float arrays with different shapes.

# %%
# Set a random seed and regenerate arrays to observe reproducibility.

# %%
# Create an array and practice finding unique values.

# %%
# Use indexing to access rows, columns and slices from arrays.

# %%
# Practice array arithmetic using addition, subtraction, multiplication and division.

# %%
# Compare arrays using greater than, less than and equality operations.

# %%
# Use aggregation functions such as sum, mean, min, max and standard deviation.

# %%
# Reshape arrays into different dimensions and verify shapes.

# %%
# Transpose a multidimensional array and study what changes.

# %%
# Create two arrays and perform dot product operations.

# %%
# Sort arrays and experiment with argsort.

# %%
# Use boolean masking to filter values meeting conditions.

# %%
# Generate sample image-like arrays and practice basic slicing.

# %%
# Explore broadcasting with arrays of different shapes.

# %%
# Create mini exercises involving practical data calculations using NumPy.

# %%
# Write a short reflection on what you observed about indexing, broadcasting and vectorized operations.
